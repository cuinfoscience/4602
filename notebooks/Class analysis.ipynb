# %%
import pandas as pd 

df = pd.read_csv("/Users/abramhandler/Downloads/class.csv")

df.colums['coder']
# Out:
#       1  negative  \
# 0     1  negative
# 1     1  positive
# 2     1  positive
# 3     1  positive
# 4     1  negative
# ..   ..       ...
# 741  30  positive
# 742  30  positive
# 743  30  positive
# 744  30  negative
# 745  30  negative
#
# ...
